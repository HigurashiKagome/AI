# %% [markdown]
# <a href="https://colab.research.google.com/github/HigurashiKagome/AI/blob/main/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_9_22_%EC%88%98%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02
# Out:
# /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02

# %%
import pandas as pd
df = pd.read_csv('data/earthquakes.csv')

# %%
# loc command
df.loc[3:10, ['title', 'mag', 'magType','type']]
# Out:
#                                                 title   mag magType  \
# 3                       M 0.4 - 9km NE of Aguanga, CA  0.44      ml
# 4                       M 2.2 - 10km NW of Avenal, CA  2.16      md
# 5   M 2.6 - 55km ESE of Punta Cana, Dominican Repu...  2.61      md
# 6                M 1.7 - 105km W of Talkeetna, Alaska  1.70      ml
# 7                    M 1.1 - 10km NW of Parkfield, CA  1.13      md
# 8                   M 0.9 - 6km NW of The Geysers, CA  0.92      md
# 9             M 4.7 - 219km SSE of Saparua, Indonesia  4.70      mb
# 10                     M 0.5 - 10km NE of Aguanga, CA  0.50      ml
#
#           type
# 3   earthquake
# 4   earthquake
# 5   earthquake
# 6   earthquake
# 7   earthquake
# 8   earthquake
# 9   earthquake
# 10  earthquake

# %%
df.loc[
    (df.place.str.contains('Arizona'))
]
# Out:
#      alert  cdi      code                                             detail  \
# 1062   NaN  NaN  60300227  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3965   NaN  NaN  60298572  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt    gap           ids   mag magType  ...  sources    status  \
# 1062  0.1666   NaN  163.0  ,uu60300227,  1.23      ml  ...     ,uu,  reviewed
# 3965  0.1577   NaN  211.0  ,uu60298572,  0.94      md  ...     ,uu,  reviewed
#
#                time                                      title  tsunami  \
# 1062  1539133978610  M 1.2 - 7km SSW of Colorado City, Arizona        0
# 3965  1538383710020  M 0.9 - 7km WSW of Colorado City, Arizona        0
#
#             type                         types     tz        updated  \
# 1062  earthquake  ,geoserve,origin,phase-data, -420.0  1539196068710
# 3965  earthquake  ,geoserve,origin,phase-data, -420.0  1538516934720
#
#                                                     url
# ...

# %%
df['mag'].sort_values(ascending=False)[0:10]
# Out:
# 5263    7.5
# 837     7.0
# 4363    6.7
# 118     6.7
# 799     6.5
# 816     6.2
# 838     6.1
# 5323    6.1
# 9211    6.0
# 862     6.0
# Name: mag, dtype: float64

# %%
df.drop(columns='alert', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-f6da8724854b> in <module>
# ----> 1 df.drop(columns='alert', inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
df
# Out:
#       cdi        code                                             detail  \
# 0     NaN    37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1     NaN    37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2     4.4    37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3     NaN    37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4     NaN    73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...   ...         ...                                                ...
# 9327  NaN    73086771  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9328  NaN    38063967  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9329  NaN  2018261000  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9330  NaN    38063959  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9331  NaN    38063935  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#           dmin  felt    gap             ids   mag magType  mmi  ... sources  \
# ...

# %%
mag = df.pop('mag')
magType = df.pop('magType')
df.columns
# Out:
# Index(['cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mmi', 'net',
#        'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time', 'title',
#        'tsunami', 'type', 'types', 'tz', 'updated', 'url'],
#       dtype='object')

# %%
df.head()
# Out:
#    cdi      code                                             detail      dmin  \
# 0  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693
# 1  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030
# 2  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370
# 3  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180
# 4  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990
#
#    felt    gap           ids  mmi net    nst  ... sources     status  \
# 0   NaN   85.0  ,ci37389218,  NaN  ci   26.0  ...    ,ci,  automatic
# 1   NaN   79.0  ,ci37389202,  NaN  ci   20.0  ...    ,ci,  automatic
# 2  28.0   21.0  ,ci37389194,  NaN  ci  111.0  ...    ,ci,  automatic
# 3   NaN   39.0  ,ci37389186,  NaN  ci   26.0  ...    ,ci,  automatic
# 4   NaN  192.0  ,nc73096941,  NaN  nc   18.0  ...    ,nc,  automatic
#
#             time                          title tsunami        type  \
# ...

# %%
additional_columns = pd.read_csv(
    'data/earthquakes.csv', usecols=['mag', 'magType']
)
pd.concat([df.head(), additional_columns.head()], axis=1)
# Out:
#    cdi      code                                             detail      dmin  \
# 0  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693
# 1  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030
# 2  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370
# 3  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180
# 4  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990
#
#    felt    gap           ids  mmi net    nst  ...           time  \
# 0   NaN   85.0  ,ci37389218,  NaN  ci   26.0  ...  1539475168010
# 1   NaN   79.0  ,ci37389202,  NaN  ci   20.0  ...  1539475129610
# 2  28.0   21.0  ,ci37389194,  NaN  ci  111.0  ...  1539475062610
# 3   NaN   39.0  ,ci37389186,  NaN  ci   26.0  ...  1539474978070
# 4   NaN  192.0  ,nc73096941,  NaN  nc   18.0  ...  1539474716050
#
#                            title  tsunami        type  \
# ...
